# %% [markdown]
# # **BERTopic - Tutorial**

# %%
# !pip install bertopic[visualization] --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.1/154.1 kB 4.7 MB/s eta 0:00:00
# WARNING: bertopic 0.16.0 does not provide the extra 'visualization'
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 29.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.9/90.9 kB 13.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 12.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 44.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 8.0 MB/s eta 0:00:00
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Building wheel for sentence-transformers (setup.py) ... done
#   Building wheel for umap-learn (setup.py) ... done

# %% [markdown]
# # **Imports**

# %%
import numpy as np
import pandas as pd
from copy import deepcopy
from bertopic import BERTopic

# %%
import re
import nltk
import spacy
import string
pd.options.mode.chained_assignment = None

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %% [markdown]
# # **Load data**

# %%
df = pd.read_excel("/content/data_negatif.xlsx")

# %%
df.head()
# Out:
#                                     stemming_content    label
# 0               overall bagus fitur terjemah twitter  negatif
# 1                                   bagus fitur twit  negatif
# 2                   aplikasi pas upload photo mental  negatif
# 3  orang ulas threads android terima kasih instag...  negatif
# 4  fiturnya bilang minim tampil bagus ringan hara...  negatif

# %%
df.head()
# Out:
#                                     stemming_content    label
# 0               overall bagus fitur terjemah twitter  negatif
# 1                                   bagus fitur twit  negatif
# 2                   aplikasi pas upload photo mental  negatif
# 3  orang ulas threads android terima kasih instag...  negatif
# 4  fiturnya bilang minim tampil bagus ringan hara...  negatif

# %%
df['stemming_content']=df['stemming_content'].str.lower()
df.head(150)
# Out:
#                                       stemming_content    label
# 0                 overall bagus fitur terjemah twitter  negatif
# 1                                     bagus fitur twit  negatif
# 2                     aplikasi pas upload photo mental  negatif
# 3    orang ulas threads android terima kasih instag...  negatif
# 4    fiturnya bilang minim tampil bagus ringan hara...  negatif
# ..                                                 ...      ...
# 145  wow twitter limit tolong ganti akun kayak ting...  negatif
# 146                                     gua pakai eror  negatif
# 147  repost threads log out buka threads log out bu...  negatif
# 148                            fitur switch akun susah  negatif
# 149                    app bagus twt reckmended banget  negatif
#
# [150 rows x 2 columns]

# %%
PUNCT_TO_REMOVE = string.punctuation
def remove_punctuation(text):
    """custom function to remove the punctuation"""
    return text.translate(str.maketrans('', '', PUNCT_TO_REMOVE))

# %%
df["stemming_content"] = df["stemming_content"].apply(lambda text: remove_punctuation(text))
df.head()
# Out:
#                                     stemming_content    label
# 0               overall bagus fitur terjemah twitter  negatif
# 1                                   bagus fitur twit  negatif
# 2                   aplikasi pas upload photo mental  negatif
# 3  orang ulas threads android terima kasih instag...  negatif
# 4  fiturnya bilang minim tampil bagus ringan hara...  negatif

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
", ".join(stopwords.words('indonesian'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# 'ada, adalah, adanya, adapun, agak, agaknya, agar, akan, akankah, akhir, akhiri, akhirnya, aku, akulah, amat, amatlah, anda, andalah, antar, antara, antaranya, apa, apaan, apabila, apakah, apalagi, apatah, artinya, asal, asalkan, atas, atau, ataukah, ataupun, awal, awalnya, bagai, bagaikan, bagaimana, bagaimanakah, bagaimanapun, bagi, bagian, bahkan, bahwa, bahwasanya, baik, bakal, bakalan, balik, banyak, bapak, baru, bawah, beberapa, begini, beginian, beginikah, beginilah, begitu, begitukah, begitulah, begitupun, bekerja, belakang, belakangan, belum, belumlah, benar, benarkah, benarlah, berada, berakhir, berakhirlah, berakhirnya, berapa, berapakah, berapalah, berapapun, berarti, berawal, berbagai, berdatangan, beri, berikan, berikut, berikutnya, berjumlah, berkali-kali, berkata, berkehendak, berkeinginan, berkenaan, berlainan, berlalu, berlangsung, berlebihan, bermacam, bermacam-macam, bermaksud, bermula, bersama
set(stopwords.words('indonesian'))
def remove_stopwords(text):
    """custom function to remove the stopwords"""
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])

# %%
df["stemming_content"] = df["stemming_content"].apply(lambda text: remove_stopwords(text))
df.head(50)
# Out:
#                                      stemming_content    label
# 0                overall bagus fitur terjemah twitter  negatif
# 1                                    bagus fitur twit  negatif
# 2                    aplikasi pas upload photo mental  negatif
# 3   orang ulas threads android terima kasih instag...  negatif
# 4   fiturnya bilang minim tampil bagus ringan hara...  negatif
# 5                                      mudah aplikasi  negatif
# 6          please pakai option not autoplay the video  negatif
# 7                   hastag tagar berita viral threads  negatif
# 8   aman bug enak pakai tolong fitur translate min...  negatif
# 9   deh bagus cuman bagus support kirim file bantu...  negatif
# 10                              discroll tampil patah  negatif
# 11                                          bug timpa  negatif
# 12                                    butuh situs web  negatif
# 13  aplikasi bagus tampil tarik unik aplikasi fitu...  negatif
# 14  aplikasi bug rusak aplikasi teks geser blok te...  negatif
# 15                 ain dark mode plis sakit mata help  negatif
# 16    lumayan save gambar simpan gambar mim meme dapa  negatif
# 17  ditambahin multi account kayak instagram pinda...  negatif
# 18                                       error xiaomi  negatif
# 19  bug aplikasi bug text numpuk timpa tolong moga...  negatif
# 20                      pas buka appnya layarny error  negatif
# 21         tinggal kasih fitur simpan foto galeri mah  negatif
# 22  pas diinstal trsu buka aplikasi eror bayang ge...  negatif
# 23  bug kayak upload gambar force close ukur dikec...  negatif
# 24  fitur aktivitas follow digabungin susah cari a...  negatif
# 25  coba aplikasi bagus gampang pakai uinya simpel...  negatif
# 26  aplikasi sempurna anti twitter matang rilis ba...  negatif
# 27  bagus aplikasi deh twitter gampang sesuai fitu...  negatif
# 28     aplikasi force close tulis thread gambar mohon  negatif
# 29  fitur download video foto saing twitter standa...  negatif
# 30                                   kudu theme gelap  negatif
# 31  aplikasi update fitur saing twitter aplikasi t...  negatif
# 32                            tunggu fitur save photo  negatif
# 33                  threadnya bagus cuman rada ngelag  negatif
# 34  aplikasi bagus alangkah mohon glitch menggangu...  negatif
# 35                         ngeleg babi ngeleg juancok  negatif
# 36                         bagus tolong fitur hashtag  negatif
# 37               moga iklan fitur bayar ganggu nyaman  negatif
# 38                                   buka eror nyepam  negatif
# 39                                   mode gelap silau  negatif
# 40                             bagus but bingung main  negatif
# 41  segi tampil bagus cuman eror ken lihat teman f...  negatif
# 42                          buka geser kayak eror kak  negatif
# 43                        woi ngelek gua cok bebayang  negatif
# 44  aplikasi bagus wajib dikembangin fitur mudah a...  negatif
# 45                                     minimal hestag  negatif
# 46                    mohon maaf app error gin tolong  negatif
# 47                      bagus mas bug server down wib  negatif
# 48  bagus suka daftar orang cari topik minat cari ...  negatif
# 49                   please fix the bug glitch screen  negatif

# %%
def remove_emoji(string):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)

# %%
df["stemming_content"] = df["stemming_content"].apply(lambda text: remove_emoji(text))
df.head(200)
# Out:
#                                       stemming_content    label
# 0                 overall bagus fitur terjemah twitter  negatif
# 1                                     bagus fitur twit  negatif
# 2                     aplikasi pas upload photo mental  negatif
# 3    orang ulas threads android terima kasih instag...  negatif
# 4    fiturnya bilang minim tampil bagus ringan hara...  negatif
# ..                                                 ...      ...
# 195                 bug salah scroll halaman aktivitas  negatif
# 196  his threads ngelag banget scroll kayak ngecras...  negatif
# 197  aplikasi keren tolong pakde zuck fitur biar li...  negatif
# 198                                  dunia medsos wana  negatif
# 199    menu beranda kayak lihat postingan orang follow  negatif
#
# [200 rows x 2 columns]

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
def lemmatize_words(text):
    return " ".join([lemmatizer.lemmatize(word) for word in text.split()])

# %%
df["stemming_content"] = df["stemming_content"].apply(lambda text: lemmatize_words(text))
df.head(200)
# Out:
#                                       stemming_content    label
# 0                 overall bagus fitur terjemah twitter  negatif
# 1                                     bagus fitur twit  negatif
# 2                      aplikasi pa upload photo mental  negatif
# 3    orang ulas thread android terima kasih instagr...  negatif
# 4    fiturnya bilang minim tampil bagus ringan hara...  negatif
# ..                                                 ...      ...
# 195                 bug salah scroll halaman aktivitas  negatif
# 196  his thread ngelag banget scroll kayak ngecrash...  negatif
# 197  aplikasi keren tolong pakde zuck fitur biar li...  negatif
# 198                                  dunia medsos wana  negatif
# 199    menu beranda kayak lihat postingan orang follow  negatif
#
# [200 rows x 2 columns]

# %%
from collections import Counter
cnt = Counter()
for text in df["stemming_content"].values:
    for word in text.split():
        cnt[word] += 1

cnt.most_common(10)
# Out:
# [('aplikasi', 376),
#  ('bagus', 258),
#  ('fitur', 243),
#  ('akun', 230),
#  ('thread', 229),
#  ('bug', 160),
#  ('tolong', 159),
#  ('instagram', 138),
#  ('kayak', 108),
#  ('banget', 105)]

# %%
FREQWORDS = set([w for (w, wc) in cnt.most_common(10)])
def remove_freqwords(text):
    """custom function to remove the frequent words"""
    return " ".join([word for word in str(text).split() if word not in FREQWORDS])

df["stemming_content"] = df["stemming_content"].apply(lambda text: remove_freqwords(text))
df.head(10)
# Out:
#                                     stemming_content    label
# 0                           overall terjemah twitter  negatif
# 1                                               twit  negatif
# 2                             pa upload photo mental  negatif
# 3  orang ulas android terima kasih meta alternati...  negatif
# 4  fiturnya bilang minim tampil ringan harap taga...  negatif
# 5                                              mudah  negatif
# 6         please pakai option not autoplay the video  negatif
# 7                          hastag tagar berita viral  negatif
# 8  aman enak pakai translate min awam bahasa gua ...  negatif
# 9  deh cuman support kirim file bantu illustrator...  negatif

# %%
docs = list(df.loc[:, "stemming_content"].values)

# %% [markdown]
# # **Creating Topics**

# %%
from sentence_transformers import SentenceTransformer

# %%
sentence_model = SentenceTransformer("sentence-transformers/all-mpnet-base-v2")
embeddings = sentence_model.encode(docs, show_progress_bar=True)
# Out:
# .gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# train_script.py:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Batches:   0%|          | 0/39 [00:00<?, ?it/s]

# %%
model = BERTopic("indolem/indobert-base-uncased",  calculate_probabilities=True)

# %%
topics, probs = model.fit_transform (docs ,embeddings)

# %% [markdown]
# # We can then extract most frequent topics:

# %%
model.get_topic_freq()
# Out:
#     Topic  Count
# 3       0    191
# 1      -1    149
# 0       1    118
# 5       2     99
# 2       3     77
# 4       4     66
# 7       5     61
# 24      6     47
# 15      7     39
# 10      8     36
# 17      9     36
# 19     10     31
# 9      11     31
# 16     12     29
# 13     13     20
# 14     14     20
# 8      15     20
# 6      16     20
# 12     17     18
# 18     18     16
# 22     19     16
# 23     20     16
# 20     21     15
# 25     22     14
# 26     23     14
# 11     24     13
# 21     25     13

# %% [markdown]
# # Get Individual Topics

# %%
model.get_topic(-1)
# Out:
# [('hapus', 0.03471894621143504),
#  ('lumayan', 0.03411554197471224),
#  ('follow', 0.03165434910557595),
#  ('keren', 0.028846860424642056),
#  ('mudah', 0.024696986668822307),
#  ('orang', 0.024579211982422914),
#  ('beranda', 0.024468730097885975),
#  ('kak', 0.022807439636412897),
#  ('bikin', 0.022438182051056906),
#  ('masuk', 0.020984612610995452)]

# %%
model.get_topic(0)
# Out:
# [('ngebug', 0.04443710050552008),
#  ('pakai', 0.040114929488717754),
#  ('bintang', 0.036596652236087344),
#  ('biru', 0.02506530609494845),
#  ('gua', 0.02452597309648824),
#  ('kasih', 0.023076521676793735),
#  ('tampil', 0.021120971663372054),
#  ('hilang', 0.020446301943357555),
#  ('centang', 0.020125638971197943),
#  ('hubung', 0.019087004507110223)]

# %%
model.get_topic(1)
# Out:
# [('twitter', 0.11627831671180291),
#  ('trending', 0.05733967581609324),
#  ('facebook', 0.033936492266079796),
#  ('topik', 0.031582182963935924),
#  ('search', 0.02991495013768877),
#  ('hastag', 0.02776622094497438),
#  ('postingan', 0.02392514548442991),
#  ('feed', 0.02360002182294799),
#  ('spam', 0.02266393263077761),
#  ('ganti', 0.022386989061395576)]

# %%
model.get_topic(2)
# Out:
# [('apk', 0.15422143064797683),
#  ('app', 0.03715049014194659),
#  ('gara', 0.030755845740149113),
#  ('buka', 0.029245287762568545),
#  ('belah', 0.0287421365361104),
#  ('gua', 0.022703132625828334),
#  ('hilang', 0.02152909201810438),
#  ('apknya', 0.02051458315123908),
#  ('pa', 0.020081934494122933),
#  ('android', 0.019140770716989407)]

# %%
model.get_topic(3)
# Out:
# [('foto', 0.1312106041747065),
#  ('video', 0.09267944760219157),
#  ('upload', 0.08374298302494255),
#  ('save', 0.05212815810431241),
#  ('simpan', 0.039270868694698036),
#  ('unggah', 0.03532674074118302),
#  ('photo', 0.027263551543719105),
#  ('thumbnail', 0.026022700261033694),
#  ('galeri', 0.026022700261033694),
#  ('the', 0.026001281013643997)]

# %%
model.get_topic(4)
# Out:
# [('translate', 0.2534151891018423),
#  ('bahasa', 0.10117595697670947),
#  ('butuh', 0.057646658024402206),
#  ('saran', 0.051226347979888086),
#  ('please', 0.04546303956746244),
#  ('kasih', 0.0397832528665306),
#  ('erti', 0.038389681381532426),
#  ('translatenya', 0.03791137070770894),
#  ('translation', 0.03791137070770894),
#  ('indonesia', 0.03364654164027222)]

# %%
model.get_topic(5)
# Out:
# [('tulis', 0.14609202816132605),
#  ('eror', 0.11680706302139868),
#  ('tumpuk', 0.09264080206244389),
#  ('timpa', 0.08458473366636396),
#  ('baca', 0.0724162878812704),
#  ('numpuk', 0.06837835821585744),
#  ('teks', 0.06689060919472842),
#  ('geser', 0.06043715368207363),
#  ('buka', 0.0596480653695541),
#  ('ui', 0.04942272091558657)]

# %%
model.get_topic(6)
# Out:
# [('lencana', 0.3515506421900213),
#  ('sembunyi', 0.1671801023285684),
#  ('bio', 0.14329723056734436),
#  ('hapus', 0.12290710263829811),
#  ('muncul', 0.12022206399686551),
#  ('sengaja', 0.10529306412902666),
#  ('tread', 0.08473019230338454),
#  ('profil', 0.0835900511642842),
#  ('pencet', 0.056486794868923024),
#  ('sesal', 0.04942993451599461)]

# %%
model.get_topic(7)
# Out:
# [('download', 0.23284706952160433),
#  ('gue', 0.055570908082230724),
#  ('aneh', 0.04864703861261002),
#  ('kali', 0.04785668324004286),
#  ('keapus', 0.04637994179365046),
#  ('eror', 0.0415505567352872),
#  ('sesal', 0.040310020398652426),
#  ('min', 0.037651138266860486),
#  ('masuk', 0.03678114756539793),
#  ('engkau', 0.035979316038384876)]

# %%
model.get_topic(8)
# Out:
# [('error', 0.3270705133207393),
#  ('typo', 0.06508675268118232),
#  ('ya', 0.05403011255744802),
#  ('kursor', 0.053280845062307666),
#  ('terkadang', 0.053280845062307666),
#  ('suka', 0.049588711285647305),
#  ('discroll', 0.048891166595733934),
#  ('teks', 0.04404545578122828),
#  ('edit', 0.04326323491172555),
#  ('tulis', 0.03847888392008697)]

# %%
model.get_topic(9)
# Out:
# [('scroll', 0.30263112687772725),
#  ('tumpu', 0.0716180297782295),
#  ('tampil', 0.06024892557820874),
#  ('scrolling', 0.057353099275764804),
#  ('parah', 0.04912672773773414),
#  ('pa', 0.04352311810386838),
#  ('blur', 0.04166835318975343),
#  ('poto', 0.04166835318975343),
#  ('glitchh', 0.04166835318975343),
#  ('langsung', 0.040404194012910975)]

# %%
model.get_topic(10)
# Out:
# [('terjemah', 0.38359171649001417),
#  ('idol', 0.12426504843082374),
#  ('teman', 0.12119670402351504),
#  ('sosmed', 0.10532602332093455),
#  ('cari', 0.09452848088826517),
#  ('erti', 0.0943746333962672),
#  ('terima', 0.08669153934744435),
#  ('vitur', 0.07728500565725961),
#  ('apkny', 0.07728500565725961),
#  ('jujurly', 0.07728500565725961)]

# %%
model.get_topic(12)
# Out:
# [('postingan', 0.1616624316377834),
#  ('posting', 0.08343949683672235),
#  ('edit', 0.0739922615779979),
#  ('kenal', 0.04556259180561823),
#  ('tool', 0.04556259180561823),
#  ('postingkan', 0.04556259180561823),
#  ('save', 0.04482047238875459),
#  ('komentar', 0.04375087032487846),
#  ('deh', 0.041856748835258806),
#  ('klik', 0.041808801341211725)]

# %%
model.get_topic(25)
# Out:
# [('terjemah', 0.3287928998485835),
#  ('bahasa', 0.29711853428906987),
#  ('asing', 0.14583603229052478),
#  ('arab', 0.11470619855152961),
#  ('bahaya', 0.1018023567577467),
#  ('ya', 0.0845086375898546),
#  ('harap', 0.08215957815593154),
#  ('pergi', 0.0713400052220858),
#  ('pantau', 0.0713400052220858),
#  ('navigasi', 0.0713400052220858)]

# %%
model.get_topic(21)
# Out:
# [('timeline', 0.3711524550229793),
#  ('follow', 0.09730420102561484),
#  ('limit', 0.0814633105444406),
#  ('timelinenya', 0.07582274141541788),
#  ('nongol', 0.07101109732248179),
#  ('filter', 0.07101109732248179),
#  ('kena', 0.06830778311834555),
#  ('biru', 0.0618715259847572),
#  ('difollow', 0.061717601853304),
#  ('refresh', 0.05951771930222069)]

# %%
model.get_topic(24)
# Out:
# [('uninstall', 0.22963396004877973),
#  ('install', 0.09490663348191948),
#  ('coba', 0.08399120612471142),
#  ('uninstal', 0.07548927463110676),
#  ('nge', 0.07397971231876953),
#  ('pa', 0.07340115053192937),
#  ('maaf', 0.06831958269466025),
#  ('instal', 0.06831958269466025),
#  ('beranda', 0.0651519740344111),
#  ('sandi', 0.059384448036114035)]

# %%
model.get_topic(11)
# Out:
# [('login', 0.21870828534335363),
#  ('out', 0.10378952035953755),
#  ('log', 0.10255416471630385),
#  ('username', 0.09779044122049561),
#  ('pakai', 0.07034933447282522),
#  ('salah', 0.06500141205948913),
#  ('account', 0.05603551979635927),
#  ('sandi', 0.048706948758684664),
#  ('password', 0.04803150072119361),
#  ('parah', 0.045303071096077986)]

# %%
model.get_topic(18)
# Out:
# [('crash', 0.49843477414598475),
#  ('parah', 0.45982617162519157),
#  ('lag', 0.1464816384890813),
#  ('layar', 0.12656942859899417),
#  ('paraahh', 0.1236560090516154),
#  ('banting', 0.1236560090516154),
#  ('broken', 0.10833771829335892),
#  ('mental', 0.10833771829335892),
#  ('buka', 0.10648284262268547),
#  ('benah', 0.09310343871169834)]

# %%
model.get_topic(16)
# Out:
# [('tampil', 0.5075369490708305),
#  ('patah', 0.24967163332063977),
#  ('uinya', 0.1789416697403862),
#  ('pecah', 0.167586189681057),
#  ('rusak', 0.13183347464017317),
#  ('tampilain', 0.11129040814645386),
#  ('akunw', 0.11129040814645386),
#  ('aplikasinyaa', 0.11129040814645386),
#  ('path', 0.11129040814645386),
#  ('pasrah', 0.11129040814645386)]

# %%
model.get_topic(19)
# Out:
# [('eror', 0.9383500729385693),
#  ('eorr', 0.3974657433801923),
#  ('suport', 0.3974657433801923),
#  ('entar', 0.34822838022865366),
#  ('pls', 0.3195386959649753),
#  ('mulu', 0.25082467420221577),
#  ('follower', 0.20341515310552633),
#  ('deh', 0.15995257590616757),
#  ('', 1e-05),
#  ('', 1e-05)]

# %%
model.get_topic(14)
# Out:
# [('gelap', 0.4681867813039889),
#  ('mode', 0.4549576111217306),
#  ('realme', 0.12031187616824611),
#  ('malam', 0.09848883481214447),
#  ('silau', 0.08463948973790758),
#  ('bawa', 0.0802079174454974),
#  ('patah', 0.06304839225268681),
#  ('hancuurr', 0.05620727684164337),
#  ('nyala', 0.05620727684164337),
#  ('offin', 0.05620727684164337)]

# %%
model.get_topic(15)
# Out:
# [('glitch', 0.2893027774416922),
#  ('dark', 0.2209747513668696),
#  ('mode', 0.16783497239551645),
#  ('fix', 0.09248138633057669),
#  ('screen', 0.07274051615462854),
#  ('for', 0.0616542575537178),
#  ('please', 0.056076362393316044),
#  ('terimakasih', 0.05210119590376148),
#  ('gelap', 0.05138635404555976),
#  ('mohon', 0.04714239188995026)]

# %%
model.get_topic(20)
# Out:
# [('hapus', 0.6240026819082244),
#  ('hilang', 0.17705392277437193),
#  ('mnghapus', 0.15039244344115388),
#  ('takutt', 0.15039244344115388),
#  ('hibur', 0.13176208981624735),
#  ('apl', 0.12090653360836906),
#  ('uninstal', 0.11323391194666015),
#  ('nomor', 0.09490663348191948),
#  ('mark', 0.09490663348191948),
#  ('anjir', 0.09490663348191948)]

# %%
model.get_topic(17)
# Out:
# [('follow', 0.17689195088410092),
#  ('follback', 0.14082873082441766),
#  ('orang', 0.1236189779115976),
#  ('random', 0.11078443247073375),
#  ('beranda', 0.10635101643852402),
#  ('tab', 0.10562154811831324),
#  ('isi', 0.10075190221841894),
#  ('notif', 0.10009139277862492),
#  ('follower', 0.0957247779320124),
#  ('difollow', 0.09179844981541856)]

# %%
model.get_topic(21)
# Out:
# [('timeline', 0.3711524550229793),
#  ('follow', 0.09730420102561484),
#  ('limit', 0.0814633105444406),
#  ('timelinenya', 0.07582274141541788),
#  ('nongol', 0.07101109732248179),
#  ('filter', 0.07101109732248179),
#  ('kena', 0.06830778311834555),
#  ('biru', 0.0618715259847572),
#  ('difollow', 0.061717601853304),
#  ('refresh', 0.05951771930222069)]

# %%
model.get_topic(13)
# Out:
# [('close', 0.5062223353685449),
#  ('force', 0.48182998332062843),
#  ('benah', 0.09310343871169834),
#  ('buka', 0.08873570218557122),
#  ('friend', 0.0618280045258077),
#  ('create', 0.0618280045258077),
#  ('anjingg', 0.0618280045258077),
#  ('huawei', 0.0618280045258077),
#  ('mention', 0.0618280045258077),
#  ('even', 0.0618280045258077)]

# %%
model.get_topic(23)
# Out:
# [('hack', 0.6971094832945965),
#  ('gara', 0.24720736387365136),
#  ('kena', 0.20277530586074907),
#  ('bikin', 0.12065814876511734),
#  ('gwe', 0.10499095108156024),
#  ('sistemnyaa', 0.10499095108156024),
#  ('passwornya', 0.10499095108156024),
#  ('nyaingi', 0.10499095108156024),
#  ('najis', 0.10499095108156024),
#  ('kelogout', 0.10499095108156024)]

# %%
model.get_topic(22)
# Out:
# [('data', 0.6437566402752682),
#  ('ambil', 0.30333894716429155),
#  ('valid', 0.19500789292804604),
#  ('ngambil', 0.19500789292804604),
#  ('many', 0.19500789292804604),
#  ('too', 0.15881167654208486),
#  ('pribadi', 0.14565354037379746),
#  ('bunda', 0.11129040814645386),
#  ('access', 0.11129040814645386),
#  ('linked', 0.11129040814645386)]

# %%
model.get_representative_docs(-1)
# Out:
# ['keren logo burung biru konek mutualan kasih limit yuk buru download seru banding sono moga berita trending biar nyaman',
#  'follow masuk home bikin sampah',
#  'orang follow beranda orang follow explore daftar follow rekomendasi follow saran cari kunci hastag']

# %%
model.get_representative_docs(0)
# Out:
# ['ngebug',
#  'moga saran min centang biru beranda minimal konten suka relevan muncul algoritma',
#  'tampil ngebug']

# %%
model.get_representative_docs(1)
# Out:
# ['topik trending twitter', 'twitter', 'twitter']

# %%
model.get_representative_docs(2)
# Out:
# ['gara apk error', 'apk buka error', 'apk orang hilang gara apk']

# %%
model.get_representative_docs(3)
# Out:
# ['bintang upload foto', 'upload foto', 'upload foto']

# %%
model.get_representative_docs(4)
# Out:
# ['translate', 'translate', 'translate']

# %%
model.get_representative_docs(5)
# Out:
# ['tulis tumpuk geser', 'tulis tumpuk', 'baca tulis tumpuk']

# %%
model.get_representative_docs(6)
# Out:
# ['lencana', 'lencana sembunyi muncul', 'lencana hapus muncul']

# %%
model.get_representative_docs(7)
# Out:
# ['kali hapus download error', 'download masuk', 'eror kali download']

# %%
model.get_representative_docs(8)
# Out:
# ['masuk error', 'suka error', 'error']

# %%
model.get_representative_docs(9)
# Out:
# ['tampil eror tumpuk scroll tampil',
#  'scroll lancar scroll enak',
#  'error scroll']

# %%
model.get_representative_docs(13)
# Out:
# ['translate force close', 'force close', 'force close']

# %%
model.get_representative_docs(21)
# Out:
# ['centang biru sampah timeline',
#  'komen pakai gif komen langsung open camera timeline beranta teman follow tindih ceklis biru pisah timeline teman follow',
#  'timeline postingan orang follow ganggu']

# %%
model.get_representative_docs(11)
# Out:
# ['repost log out buka log out buka log out repost btw update mohon info',
#  'buka salah login',
#  'login pakai pasuk username sandi login pakai sandi syekali']

# %% [markdown]
# # **Visualize Topics**

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f5288270-38d1-4b05-8e59-2a6da10510e2" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f5288270-38d1-4b05-8e59-2a6da10510e2")) {                    Plotly.newPlot(                        "f5288270-38d1-4b05-8e59-2a6da10510e2",                        [{"customdata":[[0,"ngebug | pakai | bintang | biru | gua",191],[1,"twitter | trending | facebook | topik | search",118],[2,"apk | app | gara | buka | belah",99],[3,"foto | video | upload | save | simpan",77],[4,"translate | bahasa | butuh | saran | please",66],[5,"tulis | eror | tumpuk | timpa | baca",61],[6,"lencana | sembunyi | bio | hapus | muncul",47],[7,"download | gue | aneh | kali | keapus",39],[8,"error | typo | ya | kursor | terkadang",36],[9,"scroll | tumpu | tampil | scrolling | parah",36],[10,"terjemah | idol | teman | sosmed | cari",31],[11,"login | out | log | username | pakai",31],[12,"postingan | posting | edit | kenal | tool",29],[13,"close | force | benah | buka | friend",20],[14,"gelap | mode | realme | malam | silau",20],[15,"glitch | dark | mode | fix | screen",20],[16,"tampil | patah | uinya | pecah | rusak",20],[17,"follow | follback | orang | random | beranda",18],[18,"crash | parah | lag | layar | paraahh",16],[19,"eror | eorr | suport | entar | pls",16],[20,"hapus | hilang | mnghapus | takutt | hibur",16],[21,"timeline | follow | limit | timelinenya | nongol",15],[22,"data | ambil | valid | ngambil | many",14],[23,"hack | gara | kena | bikin | gwe",14],[24,"uninstall | install | coba | uninstal | nge",13],[25,"terjemah | bahasa | asing | arab | bahaya",13]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[191,118,99,77,66,61,47,39,36,36,31,31,29,20,20,20,20,18,16,16,16,15,14,14,13,13],"sizemode":"area","sizeref":0.119375,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[4.227195739746094,3.9524800777435303,1.4897724390029907,3.1874537467956543,3.820319652557373,7.574164867401123,8.112406730651855,1.3103387355804443,-3.3034415245056152,4.504112243652344,8.135734558105469,4.788759708404541,3.3966429233551025,4.461644649505615,3.447770833969116,-3.180560827255249,7.785027503967285,5.634268283843994,4.225125789642334,7.463262557983398,7.843192100524902,6.013113975524902,4.173274517059326,5.082311630249023,1.626516580581665,3.354168653488159],"xaxis":"x","y":